# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import os

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import random
import pickle

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve

import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv(r"C:\Users\DINESH\Music\EV BATTERY\DATASET\Ev.csv")
df
# Out:
#      Model_Year        Make                Model Vehicle Class  Motor_(kW)  \
# 0          2012  Mitsubishi               i-MiEV    Subcompact          49
# 1          2012      Nissan                 LEAF      Mid-size          80
# 2          2013        Ford       Focus Electric       Compact         107
# 3          2013  Mitsubishi               i-MiEV    Subcompact          49
# 4          2013      Nissan                 LEAF      Mid-size          80
# ..          ...         ...                  ...           ...         ...
# 305        2022       Tesla  Model Y Performance    SUV: Small         312
# 306        2022  Volkswagen             ID.4 Pro    SUV: Small         150
# 307        2022  Volkswagen         ID.4 AWD Pro    SUV: Small         220
# 308        2022       Volvo    C40 Recharge Twin    SUV: Small         300
# 309        2022       Volvo   XC40 Recharge Twin    SUV: Small         300
#
#     Transmission Fuel_Type  Range_(km)  terminal_voltage  terminal_current  \
# 0             A1         B         100          4.191492         -0.004902
# 1             A1         B         117          4.190749         -0.001478
# 2             A1         B         122          3.974871         -2.012528
# 3             A1         B         100          3.951717         -2.013979
# 4             A1         B         117          4.189773          0.000021
# ..           ...       ...         ...               ...               ...
# 305           A1         B         488          3.699739         -2.012856
# 306           A1         B         422          3.511055         -2.013068
# 307           A1         B         394          3.508710         -2.010759
# 308           A1         B         364          3.506182         -2.010202
# 309           A1         B         359          3.503660         -2.010595
#
#      temperature  charge_current  charge_voltage     time  capacity  cycle  \
# 0      24.330034         -0.0006           0.000    0.000  1.856487      1
# 1      24.325993         -0.0006           4.206   16.781  1.856487      1
# 2      24.389085         -1.9982           3.062   35.703  1.856487      1
# 3      24.544752         -1.9982           3.030   53.781  1.856487      1
# 4      24.697752         -0.0006           0.000    0.000  1.846327      2
# ..           ...             ...             ...      ...       ...    ...
# 305    28.590486          1.9980           2.710  412.734  1.303410    161
# 306    31.275448          1.9980           2.531  956.313  1.297887    162
# 307    31.325760          1.9980           2.529  965.656  1.297887    162
# 308    31.384132          1.9980           2.526  975.031  1.297887    162
# 309    31.438696          1.9980           2.524  984.391  1.297887    162
#
#           SOH
# 0    0.928244
# 1    0.928244
# 2    0.928244
# 3    0.928244
# 4    0.923164
# ..        ...
# 305  0.651705
# 306  0.648944
# 307  0.648944
# 308  0.648944
# 309  0.648944
#
# [310 rows x 17 columns]

# %%
df.columns.to_list()
# Out:
# ['Model_Year',
#  'Make',
#  'Model',
#  'Vehicle Class',
#  'Motor_(kW)',
#  'Transmission',
#  'Fuel_Type',
#  'Range_(km)',
#  'terminal_voltage',
#  'terminal_current',
#  'temperature',
#  'charge_current',
#  'charge_voltage',
#  'time',
#  'capacity',
#  'cycle',
#  'SOH']

# %%
df.describe(include='all')
# Out:
#          Model_Year   Make   Model Vehicle Class  Motor_(kW) Transmission  \
# count    310.000000    310     310           310  310.000000          310
# unique          NaN     22     148             9         NaN            2
# top             NaN  Tesla  i-MiEV     Full-size         NaN           A1
# freq            NaN    120       6            70         NaN          287
# mean    2019.206452    NaN     NaN           NaN  293.206452          NaN
# std        2.655389    NaN     NaN           NaN  175.575473          NaN
# min     2012.000000    NaN     NaN           NaN   35.000000          NaN
# 25%     2017.000000    NaN     NaN           NaN  150.000000          NaN
# 50%     2020.000000    NaN     NaN           NaN  285.000000          NaN
# 75%     2022.000000    NaN     NaN           NaN  386.000000          NaN
# max     2022.000000    NaN     NaN           NaN  829.000000          NaN
#
#        Fuel_Type  Range_(km)  terminal_voltage  terminal_current  temperature  \
# count        310  310.000000        310.000000        310.000000   310.000000
# unique         1         NaN               NaN               NaN          NaN
# top            B         NaN               NaN               NaN          NaN
# freq         310         NaN               NaN               NaN          NaN
# mean         NaN  374.680645          3.592427         -1.856775    31.450834
# std          NaN  149.383949          0.212056          0.538493     3.616797
# min          NaN   92.000000          3.011347         -2.016580    23.408863
# 25%          NaN  300.750000          3.472744         -2.013376    29.431633
# 50%          NaN  385.500000          3.565428         -2.012377    31.434928
# 75%          NaN  482.500000          3.727240         -2.011314    33.478288
# max          NaN  837.000000          4.197843          0.002141    40.067325
#
#         charge_current  charge_voltage         time    capacity       cycle  \
# count       310.000000      310.000000   310.000000  310.000000  310.000000
# unique             NaN             NaN          NaN         NaN         NaN
# top                NaN             NaN          NaN         NaN         NaN
# freq               NaN             NaN          NaN         NaN         NaN
# mean          1.237577        2.489719  1259.064419    1.590565   79.245161
# std           1.469321        0.690153   861.079722    0.173711   43.749928
# min          -1.998400        0.000000     0.000000    1.297887    1.000000
# 25%           1.998000        2.495250   555.910000    1.453901   41.000000
# 50%           1.998200        2.594000  1144.125000    1.563849   83.000000
# 75%           1.998200        2.749750  1733.855250    1.771743  107.000000
# max           1.998400        4.213000  3470.000000    1.856487  162.000000
#
#                SOH
# count   310.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      0.795282
# std       0.086856
# min       0.648944
# 25%       0.726951
# 50%       0.781925
# 75%       0.885872
# max       0.928244

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Model_Year        310 non-null    int64
#  1   Make              310 non-null    object
#  2   Model             310 non-null    object
#  3   Vehicle Class     310 non-null    object
#  4   Motor_(kW)        310 non-null    int64
#  5   Transmission      310 non-null    object
#  6   Fuel_Type         310 non-null    object
#  7   Range_(km)        310 non-null    int64
#  8   terminal_voltage  310 non-null    float64
#  9   terminal_current  310 non-null    float64
#  10  temperature       310 non-null    float64
#  11  charge_current    310 non-null    float64
#  12  charge_voltage    310 non-null    float64
#  13  time              310 non-null    float64
#  14  capacity          310 non-null    float64
#  15  cycle             310 non-null    int64
#  16  SOH               310 non-null    float64
# dtypes: float64(8), int64(4), object(5)
# memory usage: 41.3+ KB

# %%
df.shape
# Out:
# (310, 17)

# %%
df["Model_Year"].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#       dtype=int64)

# %%
df["Make"].unique()
# Out:
# array(['Mitsubishi', 'Nissan', 'Ford', 'smart', 'Tesla', 'Chevrolet',
#        'BMW', 'Kia', 'Tesla ', 'Hyundai', 'Volkswagen', 'Audi', 'Jaguar',
#        'smart EQ', 'MINI', 'Porsche', 'Polestar', 'Volvo', 'Lucid',
#        'Mazda', 'Mercedes-Benz', 'Rivian'], dtype=object)

# %%
df["Model"].unique()
# Out:
# array(['i-MiEV', 'LEAF', 'Focus Electric',
#        'fortwo electric drive cabriolet', 'fortwo electric drive coupe',
#        'Model S (40 kWh)', 'Model S (60 kWh)', 'Model S (85 kWh)',
#        'Model S Performance', 'Spark EV', 'i3', 'Soul EV',
#        'Model S (70 kWh)', 'Model S (85/90 kWh)', 'Model S 70D',
#        'Model S 85D/90D', 'Model S P85D/P90D', 'LEAF (24 kWh)',
#        'LEAF (30 kWh)', 'Model S (60 kWh pre- 6/16)', 'Model S (75 kWh)',
#        'Model S 60D', 'Model S 75D', 'Model S 90D (Refresh)',
#        'Model S P90D (Refresh)', 'Model S P100D', 'Model X 60D',
#        'Model X 75D', 'Model X 90D', 'Model X P90D', 'Model X P100D',
#        'i3 (60 Ah)', 'i3 (94 Ah)', 'Bolt EV', 'IONIQ Electric',
#        'Model S 90D', 'Model S 100D', 'Model S P90D', 'Model X 100D',
#        'e-Golf', 'i3s', 'Model 3 Mid Range', 'Model 3 Long Range',
#        'Model 3 Long Range AWD', 'Model 3 Long Range AWD Performance',
#        'e-tron 55 quattro', 'i3 (120 Ah)', 'i3s (120 Ah)',
#        'Kona Electric', 'I-PACE', 'Niro EV', 'LEAF (40 kWh)',
#        'LEAF S PLUS', 'LEAF SV/SL PLUS', 'fortwo cabriolet',
#        'fortwo coupe', 'Model 3 Standard Range',
#        'Model 3 Standard Range Plus', 'Model S Standard Range',
#        'Model S Long Range', 'Model S Performance (19" Wheels)',
#        'Model S Performance (21" Wheels)', 'Model X Standard Range',
#        'Model X Long Range', 'Model X Performance (20" Wheels)',
#        'Model X Performance (22" Wheels)', 'e-tron Sportback 55 quattro',
#        'Soul EV (120 Ah)', 'Soul EV (180 Ah)', 'Cooper SE 3 Door',
#        'Taycan 4S (Performance Battery Plus)', 'Taycan Turbo',
#        'Taycan Turbo S',
#        'Model 3 Long Range AWD Performance (18" Wheels)',
#        'Model 3 Long Range AWD Performance (19" Wheels)',
#        'Model 3 Long Range AWD Performance (20" Wheels)',
#        'Model S Long Range Plus (pre-15/6/20)', 'Model S Long Range Plus',
#        'Model X Long Range Plus', 'Model Y Long Range AWD',
#        'Model Y Performance', 'Model Y Performance (21" Wheels)',
#        'Mustang Mach-E Standard Range',
#        'Mustang Mach-E Standard Range AWD',
#        'Mustang Mach-E Extended Range (19" Wheels)',
#        'Mustang Mach-E Extended Range AWD',
#        'Mustang Mach-E California Route 1',
#        'Mustang Mach-E GT Performance Edition', '2',
#        'Taycan 4S (Performance Battery)', 'Taycan 4 Cross Turismo',
#        'Taycan 4S Cross Turismo', 'Taycan Turbo Cross Turismo',
#        'Taycan Turbo S Cross Turismo', 'Model 3 Performance',
#        'Model S Plaid (19" Wheels)', 'Model S Plaid (21" Wheels)',
#        'Model Y Standard Range', 'ID.4 Pro', 'ID.4 AWD Pro',
#        'XC40 Recharge', 'e-tron S Sportback quattro (20" Wheels)',
#        'e-tron S Sportback quattro (21" or 22" Wheels)', 'e-tron GT',
#        'RS e-tron GT', 'Q4 50 e-tron quattro',
#        'Q4 50 e-tron Sportback quattro', 'i4 eDrive40 (18" Wheels)',
#        'i4 eDrive40 (19" Wheels)', 'i4 M50 xDrive (19" Wheels)',
#        'i4 M50 xDrive (20" Wheels)', 'iX xDrive50 (20" Wheels)',
#        'iX xDrive50 (21" Wheels)', 'iX xDrive50 (22" Wheels)', 'Bolt EUV',
#        'F-150 Lightning Standard Range', 'F-150 Lightning Extended Range',
#        'F-150 Lightning Platinum', 'Mustang Mach-E Extended Range',
#        'Mustang Mach-E California Route 1 AWD', 'IONIQ 5 Standard Range',
#        'IONIQ 5 Long Range', 'IONIQ 5 Long Range AWD',
#        'EV6 Standard Range', 'EV6 Long Range', 'EV6 Long Range AWD',
#        'Air Dream P AWD (19" Wheels)', 'Air Dream P AWD (21" Wheels)',
#        'Air Dream R AWD (19" Wheels)', 'Air Dream R AWD (21" Wheels)',
#        'Air Grand Touring AWD (19" Wheels)',
#        'Air Grand Touring AWD (21" Wheels)', 'MX-30',
#        'EQS 580 4MATIC Sedan', '2 Single Motor', '2 Dual Motor',
#        'Taycan GTS', 'Taycan GTS Sport Turismo', 'R1S', 'R1T',
#        'Model 3 RWD', 'Model S', 'Model X', 'Model X Plaid (20" Wheels)',
#        'Model X Plaid (22" Wheels)', 'Model Y AWD', 'C40 Recharge Twin',
#        'XC40 Recharge Twin'], dtype=object)

# %%
df["Transmission"].unique()
# Out:
# array(['A1', 'A2'], dtype=object)

# %%
sns.countplot(x=df["Motor_(kW)"])
plt.show()

# %%
sns.countplot(x=df["Range_(km)"])
plt.show()

# %%
sns.scatterplot(x=df["Motor_(kW)"],y=df["Range_(km)"])
plt.show()

# %%
sns.scatterplot(x=df["terminal_voltage"],y=df["SOH"])
plt.show()

# %%
sns.scatterplot(x=df["temperature"],y=df["SOH"])
plt.show()

# %%
df.isnull().sum()
# Out:
# Model_Year          0
# Make                0
# Model               0
# Vehicle Class       0
# Motor_(kW)          0
# Transmission        0
# Fuel_Type           0
# Range_(km)          0
# terminal_voltage    0
# terminal_current    0
# temperature         0
# charge_current      0
# charge_voltage      0
# time                0
# capacity            0
# cycle               0
# SOH                 0
# dtype: int64

# %%
df['terminal_voltage'].skew()
# Out:
# 0.12831448610724608

# %%
sns.distplot(df['terminal_voltage'])
plt.show()

# %%
df['temperature'].skew()
# Out:
# 0.04253740282177602

# %%
sns.distplot(df['temperature'])
plt.show()

# %%
sns.boxplot(x=df['terminal_voltage'])
plt.show()

# %%
sns.boxplot(x=df['temperature'])
plt.show()

# %%
df=df.drop(columns=["Model_Year","Fuel_Type","Transmission",'Model','cycle'])
df
# Out:
#            Make Vehicle Class  Motor_(kW)  Range_(km)  terminal_voltage  \
# 0    Mitsubishi    Subcompact          49         100          4.191492
# 1        Nissan      Mid-size          80         117          4.190749
# 2          Ford       Compact         107         122          3.974871
# 3    Mitsubishi    Subcompact          49         100          3.951717
# 4        Nissan      Mid-size          80         117          4.189773
# ..          ...           ...         ...         ...               ...
# 305       Tesla    SUV: Small         312         488          3.699739
# 306  Volkswagen    SUV: Small         150         422          3.511055
# 307  Volkswagen    SUV: Small         220         394          3.508710
# 308       Volvo    SUV: Small         300         364          3.506182
# 309       Volvo    SUV: Small         300         359          3.503660
#
#      terminal_current  temperature  charge_current  charge_voltage     time  \
# 0           -0.004902    24.330034         -0.0006           0.000    0.000
# 1           -0.001478    24.325993         -0.0006           4.206   16.781
# 2           -2.012528    24.389085         -1.9982           3.062   35.703
# 3           -2.013979    24.544752         -1.9982           3.030   53.781
# 4            0.000021    24.697752         -0.0006           0.000    0.000
# ..                ...          ...             ...             ...      ...
# 305         -2.012856    28.590486          1.9980           2.710  412.734
# 306         -2.013068    31.275448          1.9980           2.531  956.313
# 307         -2.010759    31.325760          1.9980           2.529  965.656
# 308         -2.010202    31.384132          1.9980           2.526  975.031
# 309         -2.010595    31.438696          1.9980           2.524  984.391
#
#      capacity       SOH
# 0    1.856487  0.928244
# 1    1.856487  0.928244
# 2    1.856487  0.928244
# 3    1.856487  0.928244
# 4    1.846327  0.923164
# ..        ...       ...
# 305  1.303410  0.651705
# 306  1.297887  0.648944
# 307  1.297887  0.648944
# 308  1.297887  0.648944
# 309  1.297887  0.648944
#
# [310 rows x 12 columns]

# %%
sns.boxplot(x=df['Range_(km)'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Make']=le.fit_transform(df['Make'])
df
# Out:
#      Make Vehicle Class  Motor_(kW)  Range_(km)  terminal_voltage  \
# 0      11    Subcompact          49         100          4.191492
# 1      12      Mid-size          80         117          4.190749
# 2       3       Compact         107         122          3.974871
# 3      11    Subcompact          49         100          3.951717
# 4      12      Mid-size          80         117          4.189773
# ..    ...           ...         ...         ...               ...
# 305    16    SUV: Small         312         488          3.699739
# 306    18    SUV: Small         150         422          3.511055
# 307    18    SUV: Small         220         394          3.508710
# 308    19    SUV: Small         300         364          3.506182
# 309    19    SUV: Small         300         359          3.503660
#
#      terminal_current  temperature  charge_current  charge_voltage     time  \
# 0           -0.004902    24.330034         -0.0006           0.000    0.000
# 1           -0.001478    24.325993         -0.0006           4.206   16.781
# 2           -2.012528    24.389085         -1.9982           3.062   35.703
# 3           -2.013979    24.544752         -1.9982           3.030   53.781
# 4            0.000021    24.697752         -0.0006           0.000    0.000
# ..                ...          ...             ...             ...      ...
# 305         -2.012856    28.590486          1.9980           2.710  412.734
# 306         -2.013068    31.275448          1.9980           2.531  956.313
# 307         -2.010759    31.325760          1.9980           2.529  965.656
# 308         -2.010202    31.384132          1.9980           2.526  975.031
# 309         -2.010595    31.438696          1.9980           2.524  984.391
#
#      capacity       SOH
# 0    1.856487  0.928244
# 1    1.856487  0.928244
# 2    1.856487  0.928244
# 3    1.856487  0.928244
# 4    1.846327  0.923164
# ..        ...       ...
# 305  1.303410  0.651705
# 306  1.297887  0.648944
# 307  1.297887  0.648944
# 308  1.297887  0.648944
# 309  1.297887  0.648944
#
# [310 rows x 12 columns]

# %%
df['Vehicle Class']=le.fit_transform(df['Vehicle Class'])
df
# Out:
#      Make  Vehicle Class  Motor_(kW)  Range_(km)  terminal_voltage  \
# 0      11              7          49         100          4.191492
# 1      12              2          80         117          4.190749
# 2       3              0         107         122          3.974871
# 3      11              7          49         100          3.951717
# 4      12              2          80         117          4.189773
# ..    ...            ...         ...         ...               ...
# 305    16              4         312         488          3.699739
# 306    18              4         150         422          3.511055
# 307    18              4         220         394          3.508710
# 308    19              4         300         364          3.506182
# 309    19              4         300         359          3.503660
#
#      terminal_current  temperature  charge_current  charge_voltage     time  \
# 0           -0.004902    24.330034         -0.0006           0.000    0.000
# 1           -0.001478    24.325993         -0.0006           4.206   16.781
# 2           -2.012528    24.389085         -1.9982           3.062   35.703
# 3           -2.013979    24.544752         -1.9982           3.030   53.781
# 4            0.000021    24.697752         -0.0006           0.000    0.000
# ..                ...          ...             ...             ...      ...
# 305         -2.012856    28.590486          1.9980           2.710  412.734
# 306         -2.013068    31.275448          1.9980           2.531  956.313
# 307         -2.010759    31.325760          1.9980           2.529  965.656
# 308         -2.010202    31.384132          1.9980           2.526  975.031
# 309         -2.010595    31.438696          1.9980           2.524  984.391
#
#      capacity       SOH
# 0    1.856487  0.928244
# 1    1.856487  0.928244
# 2    1.856487  0.928244
# 3    1.856487  0.928244
# 4    1.846327  0.923164
# ..        ...       ...
# 305  1.303410  0.651705
# 306  1.297887  0.648944
# 307  1.297887  0.648944
# 308  1.297887  0.648944
# 309  1.297887  0.648944
#
# [310 rows x 12 columns]

# %%
df.corr()
# Out:
#                       Make  Vehicle Class  Motor_(kW)  Range_(km)  \
# Make              1.000000      -0.323476    0.283480    0.149748
# Vehicle Class    -0.323476       1.000000   -0.355265   -0.336178
# Motor_(kW)        0.283480      -0.355265    1.000000    0.749344
# Range_(km)        0.149748      -0.336178    0.749344    1.000000
# terminal_voltage -0.069358       0.062933   -0.157706   -0.139490
# terminal_current  0.073332      -0.081047    0.102742    0.100771
# temperature       0.016083      -0.058118    0.176626    0.155458
# charge_current   -0.118772       0.053347    0.189222    0.292633
# charge_voltage   -0.091631       0.112989   -0.199915   -0.195090
# time              0.072365      -0.062122    0.149701    0.082423
# capacity          0.137342       0.080879   -0.307751   -0.464172
# SOH               0.137342       0.080879   -0.307751   -0.464172
#
#                   terminal_voltage  terminal_current  temperature  \
# Make                     -0.069358          0.073332     0.016083
# Vehicle Class             0.062933         -0.081047    -0.058118
# Motor_(kW)               -0.157706          0.102742     0.176626
# Range_(km)               -0.139490          0.100771     0.155458
# terminal_voltage          1.000000          0.014495    -0.946989
# terminal_current          0.014495          1.000000     0.193093
# temperature              -0.946989          0.193093     1.000000
# charge_current           -0.162956         -0.244270     0.065591
# charge_voltage            0.476686         -0.678510    -0.596138
# time                     -0.866050          0.285597     0.928284
# capacity                  0.168253          0.029608    -0.111968
# SOH                       0.168253          0.029608    -0.111968
#
#                   charge_current  charge_voltage      time  capacity       SOH
# Make                   -0.118772       -0.091631  0.072365  0.137342  0.137342
# Vehicle Class           0.053347        0.112989 -0.062122  0.080879  0.080879
# Motor_(kW)              0.189222       -0.199915  0.149701 -0.307751 -0.307751
# Range_(km)              0.292633       -0.195090  0.082423 -0.464172 -0.464172
# terminal_voltage       -0.162956        0.476686 -0.866050  0.168253  0.168253
# terminal_current       -0.244270       -0.678510  0.285597  0.029608  0.029608
# temperature             0.065591       -0.596138  0.928284 -0.111968 -0.111968
# charge_current          1.000000        0.099563 -0.093702 -0.562082 -0.562082
# charge_voltage          0.099563        1.000000 -0.623101  0.086309  0.086309
# time                   -0.093702       -0.623101  1.000000  0.129503  0.129503
# capacity               -0.562082        0.086309  0.129503  1.000000  1.000000
# SOH                    -0.562082        0.086309  0.129503  1.000000  1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of Correlations',fontsize=15)
plt.show()

# %%
x = df.drop(columns=['SOH'])
y = df['SOH']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in d:\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %%
import xgboost as xgb
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=180,max_depth=100)

#fit the model
xgb.fit(x_train,y_train)
import pickle
#save the model
pickle.dump(xgb,open(r'C:\Users\DINESH\Music\EV BATTERY\xgb.pkl','wb'))
#create the predict model
y_pred=xgb.predict(x_test)

# %%
from sklearn import metrics
print('The accuracy score..',xgb.score(x_train,y_train)*100)
# Model Evaluation
print('R^2:', metrics.r2_score(y_test, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_pred))*(len(y_test)-1)/(len(y_test)-x_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# The accuracy score.. 99.99882575354448
# R^2: 0.9999423608281188
# Adjusted R^2: 0.9999345332862584
# MAE: 0.0003812441579543901
# MSE: 4.0735560103683333e-07
# RMSE: 0.0006382441547220259

# %%
xgb_compare = pd.DataFrame({'Real Values':y_test, 'Predicted Values': y_pred})
xgb_compare.head(10)
# Out:
#      Real Values  Predicted Values
# 75      0.883936          0.883823
# 7       0.917675          0.917749
# 250     0.716696          0.717402
# 56      0.925901          0.925519
# 149     0.779883          0.779773
# 191     0.766188          0.765851
# 307     0.648944          0.649568
# 168     0.761324          0.761078
# 296     0.661837          0.661614
# 110     0.842451          0.842828

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in d:\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from lightgbm) (1.11.4)

# %%
import lightgbm as lgb
from lightgbm import LGBMRegressor

lgbm = LGBMRegressor(n_estimators=180, max_depth=100)
lgbm.fit(x_train, y_train)

import pickle
pickle.dump(lgbm, open(r'C:\Users\DINESH\Music\EV BATTERY\lgbm.pkl', 'wb'))

y_pred1 = lgbm.predict(x_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 553
# [LightGBM] [Info] Number of data points in the train set: 217, number of used features: 11
# [LightGBM] [Info] Start training from score 0.799706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print('R^2 on Training Set:', metrics.r2_score(y_train, lgbm.predict(x_train)) * 100)
print('R^2 on Test Set:', metrics.r2_score(y_test, y_pred1))
print('Adjusted R^2:', 1 - (1 - metrics.r2_score(y_test, y_pred1)) * (len(y_test) - 1) / (len(y_test) - x_train.shape[1] - 1))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R^2 on Training Set: 99.98971331918894
# R^2 on Test Set: 0.9991913090989835
# Adjusted R^2: 0.9990814868778578
# MAE: 0.0003812441579543901
# MSE: 4.0735560103683333e-07
# RMSE: 0.0006382441547220259

# %%
lgbm_compare = pd.DataFrame({'Real Values':y_test, 'Predicted Values': y_pred1})
lgbm_compare.head(10)
# Out:
#      Real Values  Predicted Values
# 75      0.883936          0.884850
# 7       0.917675          0.918873
# 250     0.716696          0.717975
# 56      0.925901          0.920892
# 149     0.779883          0.779777
# 191     0.766188          0.768115
# 307     0.648944          0.650698
# 168     0.761324          0.762273
# 296     0.661837          0.660634
# 110     0.842451          0.842878
